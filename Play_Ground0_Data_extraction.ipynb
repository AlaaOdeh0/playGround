# %%
from bs4 import BeautifulSoup             #Beautiful Soup is a Python library for pulling data out of HTML
                                         #It provides Pythonic idioms for iterating, searching, and modifying the parse tree.
import glob
import re
import os
import pandas as pd

# %%
#Print the current working directory
print("Current Working Directory:", os.getcwd())         # "getcwd" stands for "get current working directory."
                                                         #it will display the current working directory in the 
                                                         #console where the Python script is executed.
# Out:
# Current Working Directory: C:\Users\Alaa_Abdallah\OneDrive\Desktop\Play_Ground2

# %%
# Open the file in read mode   **read from just one file
with open('data/500118.txt', 'r', encoding='utf-8') as file:  
    # Read the HTML content from the file
    html_content = file.read()

# %%
# Use BeautifulSoup to parse the HTML content
soup = BeautifulSoup(html_content, 'html.parser')

# %%
#Open the file in read mode
with open('data/500118.txt', 'r', encoding='utf-8') as file:
    # Read and process each line
    for line in file:
        print(line, end='')
# Out:
# <!DOCTYPE html>
# <html lang="ar">
#
# <head>
#   <title>كيا اوبتيما موديل سنة 2014 | شو بدك من فلسطين؟</title>
# <meta name="description" content="السيارة بحالة ممتازة، جميع الاضافات وفتحة سقف بانوراما لون أسود. السعر 100 ألف شيكل، يشمل تأمين شامل 9 شهور وترخيص 9 شهور.">
# <link rel="canonical" href="https://shobiddak.com/cars?q[car_model_id_eq]=20&amp;q[car_sub_model_id_eq]=72">
# <meta property="og:site_name" content="شو بدك من فلسطين؟">
# <meta property="og:title" content="كيا اوبتيما موديل سنة 2014">
# <meta property="og:image" content="https://shobiddak.com/system/cars_logos/kia.jpg">
# <meta property="og:url" content="https://shobiddak.com/cars/500118">
# <meta property="og:type" content="website">
#
#
#
#   <link rel="shobiddak شوبدك من فلسطين؟" type="image/x-icon" href="/favicon.ico" >
#   <link rel="apple-touch-icon" href="/apple-touch-icon.png" />
#   <link rel="stylesheet" type="text/css" href="https://fonts.googleapis.com/earlyaccess/droidarabickufi" />
#   <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/5.15.3/css/all.min.css" integrity="sha512-iBBXm8fW90+nuLcSKlbmrPcLa0OT92xO1BIsZ+ywDWZCvqsWgccV3gFoRBv0z+8dLJgyAHIhR35VZc2oM/gI1w==" crossorigin="anonymous" referrerpolicy="no-referrer" />
#   <script src="/assets/application-a07b463f620ba1337d15d9576f0c5db14a6ca6beef42a340d9113c0652e4b67a.js"></script>
#
#   <link rel="stylesheet" href="https://cdn.rtlcss.com/bootstrap/v4.5.3/css/bootstrap.min.css" integrity="sha384-JvExCACAZcHNJEc7156QaHXTnQL3hQBixvj5RV5buE7vgnNEzzskDtx9NQ4p6BJe" crossorigin="anonymous">
#   <script src="https://cdn.rtlcss.com/bootstrap/v4.5.3/js/bootstrap.bundle.min.js" integrity="sha384-40ix5a3dj6/qaC7tfz0Yr+p9fqWLzzAXiwxVLt9dw7UjQzGYw6rWRhFAnRapuQyK" crossorigin="anonymous"></script>
#
#     <link rel="stylesheet" media="all" href="/assets/application-589dab281ef5418825128a7fad1c75e38fe70f4b8a2c479c8947353b256f436b.css" />
#   <meta name="csrf-param" content="authenticity_token" />
# <meta name="csrf-token" content="iRcI6JxM0u/inzRe57XELsRKgwe2Xsah+e+LmCzATPhbW+TpkRJkHycH4sRCaTw3ajLT5D7KZzdEvmxHWEe5/A==" />
#
#   <meta name="viewport" content="width=device-width, initial-scale=1">
#   <meta http-equiv="content-type" content="text/html; charset=utf-8">
#   <meta name="author" content="Shuaib Zahda شعيب زاهدة">
#   <meta name="msapplication-TileColor" content="#58595B">
#   <meta name="msapplication-TileImage" content="/images/pinned_logo.png">
#   <meta name="verify-v1" content="w2uFEQ1vXfn8F2sib438YT6HkLpgadPAKJu7eTaDDiU=">
#   <meta property="fb:admins" content="100000490708111,734502570">
#   <meta property="fb:app_id" content="175127835933823">
#   <meta property="fb:pages" content="1628859304073754" />
#
#     <!-- Global site tag (gtag.js) - Google Analytics -->
#     <script async src="https://www.googletagmanager.com/gtag/js?id=G-01F654BPWZ"></script>
#     <script>
#   window.dataLayer = window.dataLayer || [];
#     function gtag(){dataLayer.push(arguments);}
#       gtag('js', new Date());
#
#         gtag('config', 'G-01F654BPWZ');
#     </script>
#
#     <script async type='text/javascript' src='https://partner.googleadservices.com/gampad/google_service.js'></script>
#     <script type='text/javascript' src="https://www.googletagservices.com/tag/js/gpt.js"></script>
#
#     <!-- Google ads -->
#     <script type='text/javascript'>
#     var googletag = googletag || {};
#     googletag.cmd = googletag.cmd || [];
#     (function() {
#      var gads = document.createElement('script');
#      gads.async = true;
#      gads.type = 'text/javascript';
#      var useSSL = 'https:' == document.location.protocol;
#      gads.src = (useSSL ? 'https:' : 'http:') +
#      '//www.googletagservices.com/tag/js/gpt.js';
#      var node = document.getElementsByTagName('script')[0];
#      node.parentNode.insertBefore(gads, node);
#      })();
#     </script>
#
#
#
#   <script> var IR_Tag="c_b";</script>
#   <script src="//increaserev.com/ads/dfpres/mcm.js"></script>
# </head>
#
# <body class="main_content">
#
#   <div class="wide_header">
#
# <div class="top_bar">
#   <div class="confined_header">
#
#     <div class="space_placeholder"></div>
#     <table width="100%">
#       <tr height="35px">
#         <td class="advertise_button" width="155px">
#           <a href="/main_menu/advertise">
#             <i class="fa fa-plus-circle fa-2x"></i>
#            أضف إعلانك مجاناً</a>
#         </td>
#         <td class="header_buttons">
#             <a href="https://shobiddak.com/hesabi-myaccount"><i class='fa fa-sign-in-alt fa-2x'></i> تسجيل الدخول</a>
#         </td>
#         <td class="header_buttons">
#           <a href="/main_menu/whoarewe"><i class="fa fa-info-circle fa-2x"></i> من نحن</a>
#         </td>
#         <td class="header_buttons">
#           <a href="/feedbacks/new"><i class="fa fa-envelope fa-2x"></i> إتصل بنا</a>
#         </td>
#         <td class="header_buttons">
#           <a href="https://www.facebook.com/Shobiddak2008" target="_blank"><i class="fab fa-facebook fa-2x"></i></a>
#         </td>
#         <td class="header_buttons">
#           <a href="https://www.instagram.com/shobiddak.ps" target="_blank"><i class="fab fa-instagram fa-2x"></i></a>
#         </td>
#         <td class="header_buttons">
#           <form action="/search" target="_blank">
#             <input type="text" placeholder="إبحث شو بدك؟" name="text" size="25" style="height:30px; width: 100%; color: black;"/>
#           </form>
#         </td>
#       </tr>
#     </table>
#   </div>
# </div>
#
#   <div class="confined_header">
#     <div class="space_placeholder"></div>
#     <div class="header">
#       <table width="100%">
#         <tr>
#           <td align="center" id="logo">
#             <a href="/"><img alt="شو بدك من فلسطين؟" src="/assets/shobiddak_logo-d5daffede1c75dfe6e31163bfe118f96f0551d7d0cbfd26990ab9056bb5264a0.png" /></a>
#           </td>
#           <td class="top_ad" align="center">
#
# <script src="https://www.googletagservices.com/tag/js/gpt.js">
#  googletag.pubads().definePassback('/1218864/zanqa728/728x90', [728 , 90]).display();
# </script>
#
#
#           </td>
#         </tr>
#       </table>
#     </div>
#   </div>
# </div>
#
# <div id="sections_bar">
#   <div class="confined_header">
#     <nav class="navbar navbar-expand-lg navbar-light bg-light">
#       <div class="collapse navbar-collapse" id="navbarNavAltMarkup">
#         <div class="navbar-nav">
#           <a class="nav-item nav-link" href="/main_menu/palestine_guide">الدليل</a>
#           <a class="nav-item nav-link" href="/cars">سيارات</a>
#           <a class="nav-item nav-link" href="/main_menu/realestate">عقارات</a>
#           <a class="nav-item nav-link" href="/careers">توظيف</a>
#           <a class="nav-item nav-link" href="/stuffs">إعلانات عامة</a>
#           <a class="nav-item nav-link" href="/drivings/main">التؤوريا</a>
#           <a class="nav-item nav-link" href="/radios">إذاعات</a>
#           <a class="nav-item nav-link" href="/main_menu/education">تعليم</a>
#           <a class="nav-item nav-link" href="/CurrencyRates">العملات</a>
#           <a class="nav-item nav-link" href="/PalestineWeather">الطقس</a>
#           <a class="nav-item nav-link" href="/prayers/cities">أوقات الصلاة</a>
#           <a class="nav-item nav-link nav-no-border" href="/markets">تسوق اون لاين</a>
#         </div>
#       </div>
#     </nav>
#   </div>
# </div>
#
#
#
#   <div class="space_placeholder"></div>
#
#   <div class="all_contents">
#   <table width="100%">
#     <tr>
#       <td valign="top">
#
#
#
# <center>
# <script async src="https://securepubads.g.doubleclick.net/tag/js/gpt.js"></script>
# <div id='top'>
#   <script>
#      window.googletag = window.googletag || {cmd: []};
#        googletag.cmd.push(function() {
#          googletag
#            .defineSlot('/15918106/shobiddak/top', [[728, 90]], 'top')
#            .addService(googletag.pubads());
#          googletag.pubads().set('page_url', 'shobiddak.com');
#          googletag.enableServices();
#          googletag.display('top');
#      });
#   </script>
# </div>
# </center>
#
# <!-- Revive Adserver Interstitial or Floating DHTML Tag - Generated with Revive Adserver v5.0.5 -->
# <script type='text/javascript'><!--//<![CDATA[
#    var ox_u = 'https://openx.alzahidi-tech.com/revive/www/delivery/al.php?zoneid=9&layerstyle=simple&align=center&valign=middle&padding=2&closetime=33&padding=2&shifth=0&shiftv=0&closebutton=t&bordercolor=000000&nobg=t';
#    if (document.context) ox_u += '&context=' + escape(document.context);
#    document.write("<scr"+"ipt type='text/javascript' src='" + ox_u + "'></scr"+"ipt>");
# //]]>--></script>
#
#
#
# <a class="btn btn-info btn-sm btn-sm" href="/cars/500118"><i class="fa fa-arrow-circle-right" aria-hidden="true"></i></a><a class="btn btn-info btn-sm btn-sm" href="/cars"><i class="fa fa-home" aria-hidden="true"></i></a><a class="btn btn-info btn-sm btn-sm" href="#advertiser_info"> <i class="fa fa-user" aria-hidden="true"></i> المُعلن</a><a class="btn btn-info btn-sm btn-sm" href="#featureds"><i class='fa fa-car'></i> مميزة</a><a class="btn btn-info btn-sm btn-sm" href="#related"><i class='fa fa-car'></i> <i class='fa fa-car'></i></a>
#
#
#   <div class="center-image">
#     <img alt="كيا" class="img-thumbnail" src="/system/cars_logos/kia.jpg" />
#   </div>
#
#
# <table class="driving-table">
#   <tr>
#     <td width="65%">
#       <h3>كيا اوبتيما</h3>
#       <h5>موديل سنة 2014</h5>
#     </td>
#     <td>
#       <h5 class="post-price">100000 شيكل
#         <br />
#         <a target="_blank" class="btn btn-info btn-sm" data-toggle="tooltip" title="تاريخ سعر السيارة" href="/car_prices/price_history?models[car_model]=20&amp;models[car_sub_model]=72&amp;models[gear]=اوتوماتيك&amp;models[fuel]=بنزين&amp;models[year]=2014&amp;models[car_origin]=خصوصي"><i class="fa fa-chart-bar" aria-hidden="true"></i></a>
#         <a target="_blank" class="btn btn-info btn-sm" href="/car_prices/search?models[car_model]=20&amp;models[car_sub_model]=72&amp;models[gear]=اوتوماتيك&amp;models[fuel]=بنزين&amp;models[car_origin]=خصوصي">قارن الأسعار</a>
#       <a data-method="post" class="btn btn-info btn-sm" href="/cars/500118/add_to_compare">أضف للمقارنة</a>
#       <a class="btn btn-info btn-sm" href="/cars/compare_cars">مقارنة السيارات</a>
#       </h5>
#     </td>
#   </tr>
# </table>
#
# <script async type="text/javascript" src="//s7.addthis.com/js/300/addthis_widget.js#pubid=shobiddak"></script><div class="addthis_inline_share_toolbox center-image"></div>
#
# <table class="list_ads" width="100%">
#   <tr class="section_title">
#     <th width="40%">الصفة</th>
#     <th width="60%">الوصف</th>
#   </tr>
#   <tr class="list-row"><td width="40%">لون السيارة</td><td>أبيض عاجي </td></tr>
#   <tr id="row_1" class="list-row"><td width="40%">نوع الوقود</td><td>بنزين </td></tr>
#   <tr class="list-row"><td width="40%">أصل السيارة</td><td>خصوصي </td></tr>
#   <tr id="row_1" class="list-row"><td width="40%">رخصة السيارة</td><td>فلسطينية </td></tr>
#   <tr class="list-row"><td width="40%">نوع الجير</td><td>اوتوماتيك </td></tr>
#   <tr id="row_1" class="list-row"><td width="40%">الزجاج</td><td>الكتروني </td></tr>
#     <tr class="list-row"><td width="40%">قوة الماتور</td><td>2000 </td></tr>
#     <tr id="row_1" class="list-row"><td width="40%">عداد السيارة</td><td>75000 </td></tr>
#     <tr class="list-row"><td width="40%">عدد الركاب</td><td>4+1 </td></tr>
#   <tr id="row_1" class="list-row"><td width="40%">وسيلة الدفع</td><td>نقدا فقط </td></tr>
#   <tr class="list-row"><td width="40%">معروضة</td><td>للبيع فقط </td></tr>
#     <tr id="row_1" class="list-row"><td width="40%">أصحاب سابقون</td><td>يد اولى </td></tr>
#   <tr class="list-row">
#     <td valign="top">إضافات</td>
#     <td class="list-additions">
#       <ul>
#           <li>مُكيّف</li>
#
#           <li>إغلاق مركزي</li>
#
#           <li>جهاز إنذار</li>
#
#           <li>مسجل CD</li>
#
#           <li>فتحة سقف</li>
#
#           <li>جنطات مغنيسيوم</li>
#
#           <li>فرش جلد</li>
#
#           <li>وسادة حماية هوائية</li>
#       </ul>
#     </td>
#    </tr>
# </table>
#
# <div class="col-12 text-center mb-1">
#   <div class='col-12'><p class='text-center'>--- المزيد من الإعلانات في الأسفل ---</p></div><!-- Ezoic - middle728 - mid_content -->
# <div id="ezoic-pub-ad-placeholder-125">
#
# <script src="https://www.googletagservices.com/tag/js/gpt.js">
#  googletag.pubads().definePassback('/1218864/Shobiddak_728_3/728x90', [728 , 90]).display();
# </script>
#
# </div>
# </div>
#
#
#
#   <table class="create_post" width="100%">
#     <tr class="section_title">
#       <th>معلومات إضافية</th>
#     </tr>
#     <tr>
#       <td class="list-additions">
#         <ul><li>السيارة بحالة ممتازة، جميع الاضافات وفتحة سقف بانوراما لون أسود.</li><li>السعر 100 ألف شيكل، يشمل تأمين شامل 9 شهور وترخيص 9 شهور.</li></ul>
#       </td>
#     </tr>
#   </table>
#
# <div class="space_placeholder"></div>
#
# <div class="row">
#   <table class="list_ads" width="100%">
#     <tr class="section_title">
#       <th colspan="2">سعر التأمين (شيكل) *</th>
#     </tr>
#     <tr>
#       <td width="50%">طرف ثالث</td>
#       <td>
#           1340
#       </td>
#     </tr>
#     <tr>
#       <td>التكميلي (جسم المركبة)</td>
#       <td>
#           1751
#       </td>
#     </tr>
#     <tr>
#       <td>المجموع</td>
#       <td>
#           3090
#       </td>
#     </tr>
#     <tr>
#       <td colspan=2><p style='color: red; font-size: small; text-align: right;'>* سعر التأمين بناء على المعلومات الواردة في الإعلان</p></td>
#     </tr>
#   </table>
# </div>
#
# <table class="create_post" width="100%">
#   <tr id="advertiser_info">
#     <th class="section_title">معلومات المُعلن</th>
#   </tr>
# </table>
#
#
# <table class="create_post" width="100%">
#
#     <tr id="row_1" class="list-row"><td width="25%">حالة الإعلان</td><td>إعلان منتهي </td></tr>
#     <tr class="list-row"><td width="25%">تاريخ نشر الإعلان</td><td>2017-08-16 </td></tr>
#     <tr id="row_1" class="list-row"><td width="25%">تاريخ إنتهاء الإعلان</td><td>2017-09-15 </td></tr>
#
# </table>
#
#
#
# <div class="space_placeholder"></div>
# <div class="col-12 text-center mb-1">
#   <div class='col-12'><p class='text-center'>--- المزيد من الإعلانات في الأسفل ---</p></div><div class='center-image'>
#           <script type='text/javascript'><!--
#           google_ad_client = 'ca-pub-9021387890731428';
#           /* shobiddak_728x90 */
#           google_ad_slot = '3332873437/6286289197';
#           google_ad_width = 728;
#           google_ad_height = 90;
#           //-->
#           </script>
#           <script type='text/javascript'
#           src='//pagead2.googlesyndication.com/pagead/show_ads.js'>
#           </script>
#        </div>
# </div>
#
#
#
#
#   <table class="list_header featured_banner" width="100%">
#     <tr id="featureds">
#       <td class="yellow_bar"></td>
#       <td class="more_featureds" width="75%"><a href="/main_menu/list_featureds"><i class="fa fa-star"></i> الإعلانات المميزة</a></td>
#       <td class="yellow_bar"> </td>
#       <td class="new_featured_ad"><a href="/main_menu/advertise"><i class='fa fa-plus-circle'></i> أضف إعلانك هنا</a></td>
#     </tr>
#   </table>
#
#
#   <div class="center-image">
#   <table>
#     <tr>
#         </tr>
#         <tr>
#         <td class="td-card blue_bg">
#           <div class="card blue_bg">
#             <div class="center-image">
#               <div class="card-featured-image center-image">
#                 <a target="_self" href="https://shobiddak.com/users/1101/ads"><img alt="سيت ليون Excellence 2019 محرك بنزين 1500 cc - فل أضافات" src="/uploads/picture/car/name/1395873/thumb_3F8CBB6C-CF47-46A3-A45A-00EFB409E5BB.jpeg" /></a>
#               </div>
#               <div class="card-featured-text">
#                 <p class="featureds-title"><span data-nosnippet><a target="_self" href="https://shobiddak.com/users/1101/ads">سيت ليون Excellence 2019 محرك بنزين 1500 cc - فل أضافات</a></span></p>
#                   <p><span data-nosnippet>120000 شيكل - شركة الرفاعي لتجارة السيارات 0599828787</span></p>
#               </div>
#             </div>
#           </div>
#         </td>
#         <td class="td-card blue_bg">
#           <div class="card blue_bg">
#             <div class="center-image">
#               <div class="card-featured-image center-image">
#                 <a target="_self" href="/cars/784929"><img alt="هونداي سانتافيه 2020، ماتور 2000 ديزل، فل اضافات، 7ركاب " src="/uploads/picture/car/name/1473616/thumb_FB_IMG_1667933775278.jpg" /></a>
#               </div>
#               <div class="card-featured-text">
#                 <p class="featureds-title"><span data-nosnippet><a target="_self" href="/cars/784929">هونداي سانتافيه 2020، ماتور 2000 ديزل، فل اضافات، 7ركاب </a></span></p>
#                   <p><span data-nosnippet>بسعر مميز 155000 ش ع الكاش  طارق كارز 0598753755</span></p>
#               </div>
#             </div>
#           </div>
#         </td>
#         <td class="td-card blue_bg">
#           <div class="card blue_bg">
#             <div class="center-image">
#               <div class="card-featured-image center-image">
#                 <a target="_self" href="/cars/785988"><img alt="بي ام دبليو x3 سنة 2014 فل اضافات" src="/uploads/picture/car/name/1478077/thumb_AAC120F8-5E43-438D-9F26-F60C4F89499E.jpeg" /></a>
#               </div>
#               <div class="card-featured-text">
#                 <p class="featureds-title"><span data-nosnippet><a target="_self" href="/cars/785988">بي ام دبليو x3 سنة 2014 فل اضافات</a></span></p>
#                   <p><span data-nosnippet>140000 شيكل - محمد 0599362613</span></p>
#               </div>
#             </div>
#           </div>
#         </td>
#         </tr>
#         <tr>
#         <td class="td-card blue_bg">
#           <div class="card blue_bg">
#             <div class="center-image">
#               <div class="card-featured-image center-image">
#                 <a target="_self" href="/cars/784851"><img alt="بي ام دبليو x3 xdrive 20d  2019 الجيب الشبابي العائلي 4*4 " src="/uploads/picture/car/name/1473301/thumb_IMG_%D9%A2%D9%A0%D9%A2%D9%A2%D9%A1%D9%A1%D9%A0%D9%A6_%D9%A1%D9%A4%D9%A1%D9%A0%D9%A2%D9%A0.jpg" /></a>
#               </div>
#               <div class="card-featured-text">
#                 <p class="featureds-title"><span data-nosnippet><a target="_self" href="/cars/784851">بي ام دبليو x3 xdrive 20d  2019 الجيب الشبابي العائلي 4*4 </a></span></p>
#                   <p><span data-nosnippet>235000 شيكل - محمود شقير 0593830862</span></p>
#               </div>
#             </div>
#           </div>
#         </td>
#         <td class="td-card blue_bg">
#           <div class="card blue_bg">
#             <div class="center-image">
#               <div class="card-featured-image center-image">
#                 <a target="_self" href="/cars/773465"><img alt="هونداي اكسنت 2020 عداد قليل جدا وفحص نخب دهان شركة بنزين " src="/uploads/picture/car/name/1424218/thumb_2.jpg" /></a>
#               </div>
#               <div class="card-featured-text">
#                 <p class="featureds-title"><span data-nosnippet><a target="_self" href="/cars/773465">هونداي اكسنت 2020 عداد قليل جدا وفحص نخب دهان شركة بنزين </a></span></p>
#                   <p><span data-nosnippet>94000 شيكل -  hassan amer 0592175853</span></p>
#               </div>
#             </div>
#           </div>
#         </td>
#         <td class="td-card blue_bg">
#           <div class="card blue_bg">
#             <div class="center-image">
#               <div class="card-featured-image center-image">
#                 <a target="_self" href="/cars/784203"><img alt="مرسيدس بنز E250 بالحلّة الرياضية المميزة AMG Package  " src="/uploads/picture/car/name/1470402/thumb_IMG-20220603-WA0126.jpg" /></a>
#               </div>
#               <div class="card-featured-text">
#                 <p class="featureds-title"><span data-nosnippet><a target="_self" href="/cars/784203">مرسيدس بنز E250 بالحلّة الرياضية المميزة AMG Package  </a></span></p>
#                   <p><span data-nosnippet>260000 شيكل - محمد علي ابوعطوان 0598950963</span></p>
#               </div>
#             </div>
#           </div>
#         </td>
#       </tr>
#   </table>
#   </div>
#   <div class="space_placeholder"></div>
#
#
# <div class="space_placeholder"></div>
#
# <div class="col-12 text-center mb-1">
#   <div class='col-12'><p class='text-center'>--- المزيد من الإعلانات في الأسفل ---</p></div><div class="middle-ad">
#
# <script>
#   googletag.pubads().definePassback('/1218864/Hebron728x90Exclusive/728x90', [728 , 90]).display();
# </script>
# </div>
# </div>
#
#
#
#
#         <div class="space_placeholder"></div>
#
#       </td>
#       <td width="302px" valign="top">
#
#           <script src="https://www.googletagservices.com/tag/js/gpt.js">
#   googletag.pubads().definePassback('/1218864/MobilePOP', [300, 250]).display();
# </script>
#
#           <div style="height: 4px;">
# </div>
# <script src="https://www.googletagservices.com/tag/js/gpt.js">
#   googletag.pubads().definePassback('/1218864/bethlehem300x250', [300, 250]).display();
# </script>
#           <div id="fixed-side-banners">
#             <div style="height: 4px;">
# </div>
#
# <script src="https://www.googletagservices.com/tag/js/gpt.js">
#  googletag.pubads().definePassback('/302088915/shobidak/300x250', [300 , 250]).display();
# </script>
#
# <div style="height: 4px;">
# </div>
#
# <script src="https://www.googletagservices.com/tag/js/gpt.js">
#  googletag.pubads().definePassback('/1218864/Shobiddak300-600', [300 , 600]).display();
# </script>
#
# <!-- Revive Adserver Interstitial or Floating DHTML Tag - Generated with Revive Adserver v5.0.5 -->
# <script type='text/javascript'><!--//<![CDATA[
#    var ox_u = 'https://openx.alzahidi-tech.com/revive/www/delivery/al.php?zoneid=9&target=_blank&layerstyle=simple&align=center&valign=middle&padding=2&closetime=120&padding=2&shifth=0&shiftv=0&closebutton=t&nobg=t&noborder=t';
#    if (document.context) ox_u += '&context=' + escape(document.context);
#    document.write("<scr"+"ipt type='text/javascript' src='" + ox_u + "'></scr"+"ipt>");
# //]]>--></script>
#
#
#
#           </div>
#
#           <script type="text/javascript">
#             $('#fixed-side-banners').scrollToFixed({
#               marginTop: 10,
#               limit: function() {
#                 var limit = $('#footer-ad').offset().top - $('#fixed-side-banners').outerHeight(true) - 10;
#                 return limit;
#                 }
#               });
#           </script>
#       </td>
#     </tr>
#   </table>
#
#     <div id="footer-ad">
#     <a href="https://shobiddak.com/redirecters/752"><img src="https://shobiddak.com/uploads/corporation/logo/703/daftar.png" alt="daftar" width="1024px" border="0"></a>
#   </div>
#
#   <div class="footer">
#
#   <div class="space_placeholder"></div>
#   <h5 class="section_title text-light">أقسام موقع شو بدك من فلسطين؟</h5>
#   <table class="footer-menu">
#     <tr>
#       <td>
#         <h5 class="footer-title">السيارات</h5>
#         <ul>
#           <li><a href="/cars">معرض السيارات</a></li>
#           <li><a href="/car_prices/statistics">أسعار السيارات</a></li>
#           <li><a href="/insurances/start" target="_blank">حاسبة التأمين</a></li>
#           <li><a href="/drivings/main">التؤوريا</a></li>
#         </ul>
#         <h5 class="footer-title">التوظيف</h5>
#         <ul>
#           <li><a href="/careers">وظائف شاغرة</a></li>
#           <li><a href="/main_menu/cv">السيرة الذاتية</a></li>
#         </ul>
#       </td>
#       <td>
#         <h5 class="footer-title">العقارات</h5>
#         <ul>
#           <li><a href="/houses">شقق ومنازل</a></li>
#           <li><a href="/lands">أراضي</a></li>
#           <li><a href="/stores">محلات ومخازن ومكاتب</a></li>
#         </ul>
#         <h5 class="footer-title">الإعلانات</h5>
#         <ul>
#           <li><a href="/stuffs">الإعلانات العامة</a></li>
#         </ul>
#         <h5 class="footer-title">تسوق الآن</h5>
#         <ul>
#           <li><a href="/markets">السوق - مع خدمة التوصيل</a></li>
#         </ul>
#       </td>
#       <td>
#         <h5 class="footer-title">دليل فلسطين</h5>
#         <ul>
#           <li><a href="/daleels">الدليل التجاري</a></li>
#           <li><a href="/medicals">الدليل الطبي</a></li>
#           <li><a href="/crafts">الحرفيون والمهنيون</a></li>
#           <li><a href="/universities">الجامعات</a></li>
#           <li><a href="/vaccinations">تطعيم الأطفال</a></li>
#         </ul>
#
#         <h5 class="footer-title">التعليم</h5>
#         <ul>
#           <li><a href="/PalestineUniversities">الجامعات الفلسطينية</a></li>
#           <li><a href="/grades">المناهج الفلسطينية</a></li>
#         </ul>
#       </td>
#       <td>
#         <h5 class="footer-title">أوقات الصلاة</h5>
#         <ul><li><a href="/prayers/cities">أوقات الصلاة</a></li></ul>
#
#         <h5 class="footer-title">الإذاعات</h5>
#         <ul><li><a href="/radios">الإذاعات الفلسطينية</a></li></ul>
#
#         <h5 class="footer-title">الطقس والعملات</h5>
#         <ul><li><a href="/CurrencyRates">العملات </a></li></ul>
#         <ul><li><a href="/PalestineWeather">الطقس </a></li></ul>
#       </td>
#       <td>
#         <h5 class="footer-title">شو بدك</h5>
#         <ul>
#           <li><a href="/main_menu/advertise">أضف إعلانك</a></li>
#           <li><a href="/main_menu/faq">أسئلة متكررة</a></li>
#           <li><a href="/main_menu/whoarewe">من نحن</a></li>
#           <li><a href="/feedbacks/new">إتصل بنا</a></li>
#           <li><a href="/main_menu/privacy">سياسة الخصوصية</a></li>
#           <li><a href="/hesabi-myaccount">تسجيل الدخول</a></li>
#           <li><a href="https://www.facebook.com/Shobiddak2008" target="_blank">صفحة الفيسبوك</a></li>
#           <li><a href="https://www.instagram.com/shobiddak.ps" target="_blank">صفحة انستاجرام</a></li>
#         </ul>
#       </td>
#     </tr>
#   </table>
#
#     <div class="space_placeholder"></div>
#     <div class="space_placeholder"></div>
#     <p class="font-weight-bold">
#       &copy; 2008 - 2023 شو بدك من فلسطين؟
#     </p>
#     <p>
#       <a href="https://alzahidi-tech.com" target="_blank">برمجة: شعيب زاهدة</a>
#     </p>
#     <hr>
#   </div>
# <!-- Google Code for Remarketing Tag -->
# <!--------------------------------------------------
# Remarketing tags may not be associated with personally identifiable information or placed on pages related to sensitive categories. See more information and instructions on how to setup the tag on: http://google.com/ads/remarketingsetup
# --------------------------------------------------->
# <script type="text/javascript">
# /* <![CDATA[ */
# var google_conversion_id = 867324872;
# var google_custom_params = window.google_tag_params;
# var google_remarketing_only = true;
# /* ]]> */
# </script>
# <script async type="text/javascript" src="//www.googleadservices.com/pagead/conversion.js">
# </script>
# <noscript>
# <div style="display:inline;">
# <img height="1" width="1" style="border-style:none;" alt="" src="//googleads.g.doubleclick.net/pagead/viewthroughconversion/867324872/?guid=ON&amp;script=0"/>
# </div>
# </noscript>
#
#
# </div>
# </body>
# </html>

# %%
# Function to convert Arabic numerals to English numerals
def arabic_to_english(text):
    arabic_numerals = {'٠': '0', '١': '1', '٢': '2', '٣': '3', '٤': '4', '٥': '5', '٦': '6', '٧': '7', '٨': '8', '٩': '9'}
    
    if isinstance(text, str):
        for arabic, english in arabic_numerals.items():
            text = text.replace(arabic, english)
    
    return text

# %%
# Create empty lists to store data
file_names = []
car_names = []
model_years = []
prices = []
car_colors = []
fuel_types = []
car_origins = []
driving_licenses = []
lime_types = []
glass_types = []
motor_powers = []
car_speedometers = []
passenger_numbers = []
payment_methods = []
shown_statuses = []
previous_owners = []
extras = []

# %%
folder_path = 'data'

# %%
# Get a list of file paths matching a pattern (all txt files in the directory)
file_paths = sorted(glob.glob(os.path.join(folder_path, '*.txt')))

# %%
# Loop through all files
for file_path in file_paths:
    with open(file_path, 'r', encoding='utf-8') as file:
        # Read and process the entire content of the file
        content = file.read()

        # Create a BeautifulSoup object to parse the HTML content
        soup = BeautifulSoup(content, 'html.parser')

        # Extracting information from the table
        car_name = soup.h3.text.strip()
        
        model_year = soup.h5.text.strip()
        numeric_year = re.search(r'\b\d{4}\b', model_year)
        model_year = numeric_year.group() if numeric_year else ' '
        
        price_element = soup.find('h5', class_='post-price')
        price = price_element.contents[0].strip() if price_element else ' '
 
        # Remove '(شيكل)' from the price
        price = price.replace('شيكل', '')
         
        # Extracting additional information
        additional_info = None
        additional_info_table = soup.find('table', class_='create_post')
        if additional_info_table:
            ul_element = additional_info_table.find('ul')
            if ul_element:
                additional_info = [li.text.strip() for li in ul_element.find_all('li')]

        # Extracting data
        data = {}            
        data_table = soup.find('table', class_='list_ads')
        if data_table:
            rows = data_table.find_all('tr')
            for row in rows[1:]:  # Skip the first row (section_title)
                columns = row.find_all('td')
                if len(columns) == 2:
                    data_value = columns[0].text.strip()
                    info = columns[1].text.strip()
                    # Remove '+1' from Passenger Number
                    if data_value == 'عدد الركاب':
                        info = info.replace('+1', '')
                    data[data_value] = info

        # Storing information separately in variables
        file_names.append(os.path.basename(file_path))
        car_names.append(car_name)
        model_years.append(model_year)
        prices.append(price)
        
        car_colors.append(data.get('لون السيارة', ''))
        fuel_types.append(data.get('نوع الوقود', ''))
        car_origins.append(data.get('أصل السيارة', ''))
        driving_licenses.append(data.get('رخصة السيارة', ''))
        lime_types.append(data.get('نوع الجير', ''))
        glass_types.append(data.get('الزجاج', ''))
        motor_powers.append(data.get('قوة الماتور', ''))
        
        # Convert Arabic numerals to English in 'Car Speedometer' and 'Passenger Number' columns          
        car_speedometer = arabic_to_english(data.get('عداد السيارة', ''))
        passenger_number = arabic_to_english(data.get('عدد الركاب', ''))
        Previous_Owner = arabic_to_english(data.get('أصحاب سابقون', ''))
        
        car_speedometers.append(car_speedometer)
        passenger_numbers.append(passenger_number)
        previous_owners.append(Previous_Owner)
        
        
        payment_methods.append(data.get('وسيلة الدفع', '').replace('فقط', ''))
        shown_statuses.append(data.get('معروضة', '').replace('فقط', ''))

         # Save 'فتحة سقف' in the "Extras" column if found
        extras.append('فتحة سقف' if 'فتحة سقف' in data.get('إضافات', '') else '')

# %%
# Create a DataFrame from the lists
df = pd.DataFrame({
    'File Name': file_names,
    'Car Name': car_names,
    'Model Year': model_years,
    'Price': prices,
    'Car Color': car_colors,
    'Fuel Type': fuel_types,
    'Car Origin': car_origins,
    'Driving License': driving_licenses,
    'Lime Type': lime_types,
    'Glass Type': glass_types,
    'Motor Power': motor_powers,
    'Car Speedometer': car_speedometers,
    'Passenger Number': passenger_numbers,
    'Payment Method': payment_methods,
    'Shown Status': shown_statuses,
    'Previous Owners': previous_owners,
    'Extras': extras
})

# %%
# Display the DataFrame
df
# Out:
#        File Name              Car Name Model Year    Price  Car Color  \
# 0     500118.txt           كيا اوبتيما       2014  100000   أبيض عاجي
# 1     500125.txt         معرض السيارات
# 2     500132.txt         معرض السيارات
# 3     500163.txt           كيا سورينتو       2007   60000        سكني
# 4     500226.txt         هونداي افانتي       2006   43500        سكني
# ...          ...                   ...        ...      ...        ...
# 7772  777932.txt          فورد ترانزيت       2002   48000        أبيض
# 7773  777937.txt           بيجو بارتنر       2018   87000         فضي
# 7774  777960.txt           كيا سورينتو       2017  126000      بترولي
# 7775  777963.txt         معرض السيارات
# 7776  777979.txt  فولكسفاجن ترانسبورتر       2001   28000        أبيض
#
#      Fuel Type Car Origin Driving License      Lime Type Glass Type  \
# 0        بنزين      خصوصي        فلسطينية      اوتوماتيك   الكتروني
# 1
# 2
# 3         ديزل      خصوصي        فلسطينية  نصف اوتوماتيك   الكتروني
# 4        بنزين      خصوصي        فلسطينية      اوتوماتيك   الكتروني
# ...        ...        ...             ...            ...        ...
# 7772      ديزل      عمومي        فلسطينية           عادي   الكتروني
# 7773      ديزل      خصوصي        فلسطينية           عادي   الكتروني
# 7774      ديزل      خصوصي        فلسطينية      اوتوماتيك   الكتروني
# 7775
# 7776      ديزل      عمومي        فلسطينية           عادي   الكتروني
#
#      Motor Power Car Speedometer Passenger Number   Payment Method  \
# 0           2000           75000                4            نقدا
# 1
# 2
# 3           2500          130000                7  إمكانية التقسيط
# 4           1600                                             نقدا
# ...          ...             ...              ...              ...
# 7772        2400           00000                7            نقدا
# 7773        1600           50000                4            نقدا
# 7774        2200             100                6            نقدا
# 7775
# 7776        2500         7686866                7            نقدا
#
#           Shown Status Previous Owners    Extras
# 0               للبيع          يد اولى  فتحة سقف
# 1
# 2
# 3     للبيع أو التبديل               2  فتحة سقف
# 4               للبيع
# ...                ...             ...       ...
# 7772            للبيع                5
# 7773            للبيع           يد صفر
# 7774            للبيع            ثانيه  فتحة سقف
# 7775
# 7776  للبيع أو التبديل           خامسة
#
# [7777 rows x 17 columns]

# %%
# Save the DataFrame to an Excel file              
df.to_excel('Data_file.xlsx', index=False)
